# %%
import pandas as pd
import numpy as np
from transformers import AutoFeatureExtractor
import librosa
import soundfile as sf
import resampy
from pydub import AudioSegment
from tqdm.notebook import tqdm

# %%
df = pd.read_pickle('AnnoMI-full-with-audio-cleaned-text.pkl')

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-large" , sampling_rate=16000, return_attention_mask=True)

# %%
# audio, _ = librosa.load('current_wav2vec.wav', sr=16000)
    
    
# inputs = feature_extractor(audio, sampling_rate=feature_extractor.sampling_rate, max_length= 16000, truncation=True)

# inputs['input_values']

# np.array(inputs['input_values']).shape

# %%
def resample_audio(filename, target_sr):
    y, sr = librosa.load(filename, sr=None)  # Load with the original sample rate
    y_resampled = resampy.resample(y, sr, target_sr)  # Resample to target sample rate
    sf.write(filename, y_resampled, target_sr)

def compute_embeddings(audio_list):
    # If audio_list is empty, pad with silence
    if audio_list is None:
        return None
    if len(audio_list) == 0:
        pad_ms = 1000  # milliseconds of silence needed
        silence = AudioSegment.silent(duration=pad_ms)
        silence.export('current_wav2vec.wav', format='wav')
        resample_audio('current_wav2vec.wav', 16000)
    else:
        audio_list = audio_list.tolist()
        
        # Print the length of the audio list and calculate the duration
        print(f"Length of audio list: {len(audio_list)}")
        print(f"Original duration: {len(audio_list) / 44100} seconds")
        
        # Save the audio data with its original sampling rate
        sf.write('current_wav2vec.wav', audio_list, 44100)

    # Resample to the desired sampling rate
    resample_audio('current_wav2vec.wav', 16000)

    # Load the resampled audio
    audio, _ = librosa.load('current_wav2vec.wav', sr=16000)
    print(f"Resampled duration: {len(audio) / 16000} seconds")
    
    
    inputs = feature_extractor(audio, sampling_rate=feature_extractor.sampling_rate)
    # inputs = np.array(inputs['input_values'])
    
    return inputs

# %%
# Create two new columns for embeddings and initialize with None
df['client_wav2vec_emb'] = None
df['therapist_wav2vec_emb'] = None

# Iterate through the DataFrame
for index, row in tqdm(df.iterrows(), total=df.shape[0], desc='Processing'):
    # Determine the role (client or therapist) from the interlocutor column
    role = row['interlocutor']
    video_title = row['video_title']
    utterance = row['utterance_id']
    
    print(f'Processing {role} {utterance} {video_title}...')

    audio_list = row[f'{role}_audio_utterance']

    # Compute the embeddings for the given role
    embeddings = compute_embeddings(audio_list)

    # Save the embeddings in the DataFrame
    df.at[index, f'{role}_wav2vec_emb'] = embeddings
# Out:
# Processing:   0%|          | 0/12778 [00:00<?, ?it/s]
# Processing therapist 0 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 1 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 2 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 3 NEW VIDEO: Brief intervention: "Barbara"...
# Resampled duration: 1.0 seconds
# Processing therapist 4 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 5 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 6 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 7 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 8 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 705600
# Original duration: 16.0 seconds
# Resampled duration: 16.0 seconds
# Processing client 9 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 10 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 11 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 617400
# Original duration: 14.0 seconds
# Resampled duration: 14.0 seconds
# Processing therapist 12 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 13 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 14 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 661500
# Original duration: 15.0 seconds
# Resampled duration: 15.0 seconds
# Processing client 15 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 16 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 17 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing therapist 18 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 19 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 20 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 882000
# Original duration: 20.0 seconds
# Resampled duration: 20.0 seconds
# Processing client 21 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 22 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 23 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing therapist 24 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 25 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 26 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing client 27 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 28 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 29 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 30 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 31 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 32 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 1146600
# Original duration: 26.0 seconds
# Resampled duration: 26.0 seconds
# Processing client 33 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 34 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 35 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 705600
# Original duration: 16.0 seconds
# Resampled duration: 16.0 seconds
# Processing therapist 36 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing client 37 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 38 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 39 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing therapist 40 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 41 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 42 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 43 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 44 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 45 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing therapist 46 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 47 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 48 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing client 49 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 50 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 51 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 52 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 53 NEW VIDEO: Brief intervention: "Barbara"...
# Length of audio list: 251105
# Original duration: 5.693990929705215 seconds
# Resampled duration: 5.6939375 seconds
# Processing therapist 0 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 1 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 2 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 3 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 4 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 5 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 6 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 1014300
# Original duration: 23.0 seconds
# Resampled duration: 23.0 seconds
# Processing client 7 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 8 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 9 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing therapist 10 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 11 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 12 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 13 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 14 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 15 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 16 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 17 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 18 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 19 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 20 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 1323000
# Original duration: 30.0 seconds
# Resampled duration: 30.0 seconds
# Processing client 21 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 22 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 23 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing therapist 24 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 25 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing therapist 26 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 27 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 28 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing client 29 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 30 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 31 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 32 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 33 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 34 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 1411200
# Original duration: 32.0 seconds
# Resampled duration: 32.0 seconds
# Processing client 35 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 36 NEW VIDEO: Brief intervention: "Dave"...
# Length of audio list: 314609
# Original duration: 7.133990929705216 seconds
# Resampled duration: 7.1339375 seconds
# Processing therapist 0 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 1 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing therapist 2 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 3 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 4 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 5 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 793800
# Original duration: 18.0 seconds
# Resampled duration: 18.0 seconds
# Processing therapist 6 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 7 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 8 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 9 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 10 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 11 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 793800
# Original duration: 18.0 seconds
# Resampled duration: 18.0 seconds
# Processing therapist 12 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing client 13 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 14 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 793800
# Original duration: 18.0 seconds
# Resampled duration: 18.0 seconds
# Processing client 15 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 16 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 17 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 18 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 749700
# Original duration: 17.0 seconds
# Resampled duration: 17.0 seconds
# Processing client 19 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 20 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 21 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 22 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 23 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 24 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 25 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing therapist 26 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 27 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 28 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 970200
# Original duration: 22.0 seconds
# Resampled duration: 22.0 seconds
# Processing client 29 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 30 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 31 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 32 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing client 33 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 34 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 35 Motivational Interviewing: Evoking Commitment to Change...
# Length of audio list: 399281
# Original duration: 9.053990929705215 seconds
# Resampled duration: 9.0539375 seconds
# Processing client 0 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 793800
# Original duration: 18.0 seconds
# Resampled duration: 18.0 seconds
# Processing therapist 1 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 2 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 3 How to Do Motivational Interviewing (MI) Role Play -1...
# Resampled duration: 1.0 seconds
# Processing client 4 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing therapist 5 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 6 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 7 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 8 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 9 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 10 How to Do Motivational Interviewing (MI) Role Play -1...
# Resampled duration: 1.0 seconds
# Processing therapist 11 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 12 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 573300
# Original duration: 13.0 seconds
# Resampled duration: 13.0 seconds
# Processing therapist 13 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 14 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 15 How to Do Motivational Interviewing (MI) Role Play -1...
# Length of audio list: 17235206
# Original duration: 390.8209977324263 seconds
# Resampled duration: 390.8209375 seconds
# Processing therapist 0 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 1 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 2 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 3 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 4 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 5 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 6 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 7 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 8 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing client 9 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 10 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 11 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing therapist 12 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 13 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 14 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 15 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 16 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 617400
# Original duration: 14.0 seconds
# Resampled duration: 14.0 seconds
# Processing client 17 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing therapist 18 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 19 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 20 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 21 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 22 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 23 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 24 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 25 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 26 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 27 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 28 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 29 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing therapist 30 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 31 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing therapist 32 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing client 33 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 34 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 35 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 36 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 37 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 38 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 39 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 40 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 41 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 42 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 43 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 44 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 45 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 46 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing client 47 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 48 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 49 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 50 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 51 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 52 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 53 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 54 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 55 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 56 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 57 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Resampled duration: 1.0 seconds
# Processing therapist 58 Motivational Interviewing in Dental Practice Emily's Oral Piercing...
# Length of audio list: 418685
# Original duration: 9.493990929705216 seconds
# Resampled duration: 9.4939375 seconds
# Processing therapist 0 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 1 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 2 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 3 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 4 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 5 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 6 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 882000
# Original duration: 20.0 seconds
# Resampled duration: 20.0 seconds
# Processing client 7 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 8 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 9 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 10 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 11 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 12 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 13 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 14 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 15 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing therapist 16 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 17 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 18 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 19 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 20 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 21 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 22 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 23 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 24 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 25 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 26 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing client 27 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 28 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 29 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 30 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 31 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing therapist 32 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 33 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 34 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 35 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 36 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 37 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 38 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 39 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 40 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 41 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 42 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 43 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 44 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 45 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 46 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 573300
# Original duration: 13.0 seconds
# Resampled duration: 13.0 seconds
# Processing client 47 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 48 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 49 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 50 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 485100
# Original duration: 11.0 seconds
# Resampled duration: 11.0 seconds
# Processing client 51 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 52 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 53 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 54 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 55 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 56 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing client 57 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 58 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 59 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 60 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 61 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 62 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 63 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 64 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 65 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 66 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 67 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 68 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 69 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 70 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 705600
# Original duration: 16.0 seconds
# Resampled duration: 16.0 seconds
# Processing client 71 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 661500
# Original duration: 15.0 seconds
# Resampled duration: 15.0 seconds
# Processing therapist 72 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 73 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 74 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 75 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 76 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 77 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 78 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 79 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 80 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 81 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 82 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 83 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing therapist 84 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 85 Motivational Techniques - Margaret interview Billy - 3...
# Resampled duration: 1.0 seconds
# Processing therapist 86 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 87 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 88 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 89 Motivational Techniques - Margaret interview Billy - 3...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 90 Motivational Techniques - Margaret interview Billy - 3...
# ...
# Length of audio list: 1014300
# Original duration: 23.0 seconds
# Resampled duration: 23.0 seconds
# Processing therapist 19 The TEACH Project - The Ineffective Health Practitioner...
# Length of audio list: 1014300
# Original duration: 23.0 seconds
# Resampled duration: 23.0 seconds
# Processing therapist 19 The TEACH Project - The Ineffective Health Practitioner...
# Length of audio list: 1014300
# Original duration: 23.0 seconds
# Resampled duration: 23.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing client 20 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 21 The TEACH Project - The Ineffective Health Practitioner...
# Resampled duration: 1.0 seconds
# Processing therapist 0 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 1 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 2 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 3 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 4 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 5 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 6 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 7 Stop smoking - initial consultation...
# Length of audio list: 793800
# Original duration: 18.0 seconds
# Resampled duration: 18.0 seconds
# Processing therapist 8 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 9 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 10 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 11 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 12 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 13 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 14 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 15 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 16 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 17 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 18 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing client 19 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 20 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 21 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 22 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 23 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 24 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 25 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 26 Stop smoking - initial consultation...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing client 27 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 28 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 29 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 30 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 31 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 32 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 33 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 34 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 35 Stop smoking - initial consultation...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 36 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing client 37 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 38 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 39 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 40 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 41 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing therapist 42 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing client 43 Stop smoking - initial consultation...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing therapist 44 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 45 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 46 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 47 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 48 Stop smoking - initial consultation...
# Length of audio list: 220500
# Original duration: 5.0 seconds
# Resampled duration: 5.0 seconds
# Processing client 49 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 50 Stop smoking - initial consultation...
# Length of audio list: 441000
# Original duration: 10.0 seconds
# Resampled duration: 10.0 seconds
# Processing client 51 Stop smoking - initial consultation...
# Length of audio list: 661500
# Original duration: 15.0 seconds
# Resampled duration: 15.0 seconds
# Processing therapist 52 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 53 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 54 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing client 55 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 56 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 57 Stop smoking - initial consultation...
# Length of audio list: 308700
# Original duration: 7.0 seconds
# Resampled duration: 7.0 seconds
# Processing therapist 58 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 59 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 60 Stop smoking - initial consultation...
# Length of audio list: 529200
# Original duration: 12.0 seconds
# Resampled duration: 12.0 seconds
# Processing client 61 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 62 Stop smoking - initial consultation...
# Length of audio list: 352800
# Original duration: 8.0 seconds
# Resampled duration: 8.0 seconds
# Processing client 63 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 64 Stop smoking - initial consultation...
# Length of audio list: 661500
# Original duration: 15.0 seconds
# Resampled duration: 15.0 seconds
# Processing client 65 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 66 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 67 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 68 Stop smoking - initial consultation...
# Length of audio list: 1234800
# Original duration: 28.0 seconds
# Resampled duration: 28.0 seconds
# Processing client 69 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 70 Stop smoking - initial consultation...
# Length of audio list: 396900
# Original duration: 9.0 seconds
# Resampled duration: 9.0 seconds
# Processing client 71 Stop smoking - initial consultation...
# Length of audio list: 176400
# Original duration: 4.0 seconds
# Resampled duration: 4.0 seconds
# Processing therapist 72 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing client 73 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 74 Stop smoking - initial consultation...
# Length of audio list: 1455300
# Original duration: 33.0 seconds
# Resampled duration: 33.0 seconds
# Processing client 75 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 76 Stop smoking - initial consultation...
# Length of audio list: 1146600
# Original duration: 26.0 seconds
# Resampled duration: 26.0 seconds
# Processing client 77 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing therapist 78 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing client 79 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 80 Stop smoking - initial consultation...
# Length of audio list: 264600
# Original duration: 6.0 seconds
# Resampled duration: 6.0 seconds
# Processing client 81 Stop smoking - initial consultation...
# Resampled duration: 1.0 seconds
# Processing therapist 82 Stop smoking - initial consultation...
# Length of audio list: 573300
# Original duration: 13.0 seconds
# Resampled duration: 13.0 seconds
# Processing client 83 Stop smoking - initial consultation...
# Length of audio list: 88200
# Original duration: 2.0 seconds
# Resampled duration: 2.0 seconds
# Processing therapist 84 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing client 85 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 86 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 87 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 88 Stop smoking - initial consultation...
# Length of audio list: 132300
# Original duration: 3.0 seconds
# Resampled duration: 3.0 seconds
# Processing client 89 Stop smoking - initial consultation...
# Length of audio list: 44100
# Original duration: 1.0 seconds
# Resampled duration: 1.0 seconds
# Processing therapist 90 Stop smoking - initial consultation...
# Length of audio list: 222881
# Original duration: 5.053990929705216 seconds
# Resampled duration: 5.0539375 seconds

# %%
df.to_pickle('AnnoMI-wav2vec-new.pkl')
